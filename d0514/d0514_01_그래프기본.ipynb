# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows 한글 폰트
matplotlib.rcParams['axes.unicode_minus'] = False # - 기호 깨짐 현상을 해결함
# matplotlib.rcParams['font.size'] = '15' # 폰트 사이즈 지정
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
import seaborn as sns

# %%
x=[1,2,3]
y=[2,4,8]
y2=[1,4,9]
y3=[7,5,2]

plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
plt.plot(x,y)
plt.title('Line graph') # 상단 타이틀 제목넣기
# Out:
# Text(0.5, 1.0, 'Line graph')

# %%
plt.plot(x,y)
plt.title('막대그래프') # 한글 깨짐 -> 라이브러리에서 글꼴 지정 해줘야함
# plt.show() # 그래프만 화면에 보이고 실행 문구 사라진다. (Text(0.5, 1.0, '막대그래프'))
# Out:
# Text(0.5, 1.0, '막대그래프')

# %%
x = [-3,-2,-1,0,1,2,3]
y = [2,4,8,10,5,2,9]

plt.plot(x,y)
