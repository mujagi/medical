# %%
import pandas as pd
df = pd.read_csv('stu_score1.csv')
df.set_index('no',inplace=True)
df
# Out:
#           name  kor  eng  math  total        avg  rank      c_date
# no
# 1      Michell   55   87    68    210  70.000000     0  2024-04-04
# 2       Ricard   73   69    77    219  73.000000     0  2024-04-01
# 3       Goraud   92   97    90    279  93.000000     0  2024-04-04
# 4        Melli   98   60    78    236  78.666667     0  2024-04-04
# 5       Jo-ann   66   72    59    197  65.666667     0  2024-04-06
# ...        ...  ...  ...   ...    ...        ...   ...         ...
# 996      Danna   59   64    51    174  58.000000     0  2024-04-01
# 997   Gilberta   89   53    54    196  65.333333     0  2024-04-06
# 998     Pansie   63   82    78    223  74.333333     0  2024-04-02
# 999    Laurena   61   60    96    217  72.333333     0  2024-04-07
# 1000   Klemens   83   64    56    203  67.666667     0  2024-04-08
#
# [1000 rows x 8 columns]

# %%
# stu_score1.csv 를 for문을 사용하여 콘솔창에 출력하시오
data_list = []
f = open('stu_score1.csv','r',encoding='utf8')
while True :
    data = f.readline()
    if data == '' :
        break
    data_list.append(data.split(","))
print(data_list)
    # dict 타입의 list로 저장하시오.
# Out:
# [['no', 'name', 'kor', 'eng', 'math', 'total', 'avg', 'rank', 'c_date\n'], ['1', 'Michell', '55', '87', '68', '210', '70', '0', '2024-04-04\n'], ['2', 'Ricard', '73', '69', '77', '219', '73', '0', '2024-04-01\n'], ['3', 'Goraud', '92', '97', '90', '279', '93', '0', '2024-04-04\n'], ['4', 'Melli', '98', '60', '78', '236', '78.6666666667', '0', '2024-04-04\n'], ['5', 'Jo-ann', '66', '72', '59', '197', '65.6666666667', '0', '2024-04-06\n'], ['6', 'Maximilien', '64', '66', '63', '193', '64.3333333333', '0', '2024-04-08\n'], ['7', 'Billi', '84', '81', '97', '262', '87.3333333333', '0', '2024-04-02\n'], ['8', 'Amelia', '58', '69', '95', '222', '74', '0', '2024-04-02\n'], ['9', 'Otho', '95', '58', '72', '225', '75', '0', '2024-04-03\n'], ['10', 'Danya', '60', '97', '72', '229', '76.3333333333', '0', '2024-04-09\n'], ['11', 'Toiboid', '63', '99', '87', '249', '83', '0', '2024-04-09\n'], ['12', 'Mendel', '80', '59', '72', '211', '70.3333333333', '0', '2024-04-01\n'], ['13', 'Elnora', '74', '91', '76', '241', '80.3333333333', '0', '2024-04-03\n'], ['14', 'Krysta', '77', '65', '79', '221', '73.6666666667', '0', '2024-04-05\n'], ['15', 'Ward', '81', '55', '91', '227', '75.6666666667', '0', '2024-04-08\n'], ['16', 'Bella', '82', '100', '50', '232', '77.3333333333', '0', '2024-04-01\n'], ['17', 'Teri', '77', '100', '81', '258', '86', '0', '2024-04-01\n'], ['18', 'Pegeen', '90', '80', '97', '267', '89', '0', '2024-04-08\n'], ['19', 'Tresa', '50', '91', '56', '197', '65