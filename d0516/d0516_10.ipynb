# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import requests
import oracledb
matplotlib.rcParams['axes.unicode_minus'] = False # - 기호 깨짐 현상을 해결함
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows 한글 폰트
matplotlib.rcParams['font.size'] = '10' # font size

# %%
#http -> 보안키가 적용되어 데이터 넣어옴
url = "https://api.odcloud.kr/api/3051434/v1/uddi:a9238a42-556e-4feb-8e2e-f89c7ff72fb9_201706131814?page=1&perPage=10&serviceKey=mLkrtLTDhyoDx6NwQykQZVfcR3F9kIMAI70WGjYRqNJ2uGezAcBS%2FyCYK8UinPOti9Fvw%2BXruLYoNYdoYVtj7g%3D%3D"
res = requests.get(url)
res.text
# Out:
# '{"currentCount":10,"data":[{"기관부담금(천원)":"5390627489","시도":"전국","입내원일수":"96329691","종별":"1종","진료건수":"61005932","진료실인원":"1147555","진료일수":"478676699","진료형태":"계","총진료비(천원)":"5443835740"},{"기관부담금(천원)":"3031441055","시도":"전국","입내원일수":"37763697","종별":"1종","진료건수":"2226345","진료실인원":"365012","진료일수":"43130721","진료형태":"입원","총진료비(천원)":"3031986806"},{"기관부담금(천원)":"1512928134","시도":"전국","입내원일수":"38854295","종별":"1종","진료건수":"39067888","진료실인원":"1101057","진료일수":"110371962","진료형태":"외래","총진료비(천원)":"1558048973"},{"기관부담금(천원)":"846258300","시도":"전국","입내원일수":"19711699","종별":"1종","진료건수":"19711699","진료실인원":"1028970","진료일수":"325174016","진료형태":"약국","총진료비(천원)":"853799960"},{"기관부담금(천원)":"779748814","시도":"서울","입내원일수":"13185805","종별":"1종","진료건수":"9514703","진료실인원":"179395","진료일수":"76975028","진료형태":"계","총진료비(천원)":"788163801"},{"기관부담금(천원)":"382328645","시도":"서울","입내원일수":"3997689","종별":"1종","진료건수":"241674","진료실인원":"47024","진료일수":"4772046","진료형태":"입원","총진료비(천원)":"382416025"},{"기관부담금(천원)":"260504054","시도":"서울","입내원일수":"61616
# ...

# %%
#json 데이터 변경
json_data = res.json()
json_data
# Out:
# {'currentCount': 10,
#  'data': [{'기관부담금(천원)': '5390627489',
#    '시도': '전국',
#    '입내원일수': '96329691',
#    '종별': '1종',
#    '진료건수': '61005932',
#    '진료실인원': '1147555',
#    '진료일수': '478676699',
#    '진료형태': '계',
#    '총진료비(천원)': '5443835740'},
#   {'기관부담금(천원)': '3031441055',
#    '시도': '전국',
#    '입내원일수': '37763697',
#    '종별': '1종',
#    '진료건수': '2226345',
#    '진료실인원': '365012',
#    '진료일수': '43130721',
#    '진료형태': '입원',
#    '총진료비(천원)': '3031986806'},
#   {'기관부담금(천원)': '1512928134',
#    '시도': '전국',
#    '입내원일수': '38854295',
#    '종별': '1종',
#    '진료건수': '39067888',
#    '진료실인원': '1101057',
#    '진료일수': '110371962',
#    '진료형태': '외래',
#    '총진료비(천원)': '1558048973'},
#   {'기관부담금(천원)': '846258300',
#    '시도': '전국',
#    '입내원일수': '19711699',
#    '종별': '1종',
#    '진료건수': '19711699',
#    '진료실인원': '1028970',
#    '진료일수': '325174016',
#    '진료형태': '약국',
#    '총진료비(천원)': '853799960'},
#   {'기관부담금(천원)': '779748814',
#    '시도': '서울',
#    '입내원일수': '13185805',
#    '종별': '1종',
# ...

# %%
datas =json_data['data']
type[datas]
# Out:
# type[[{'기관부담금(천원)': '5390627489', '시도': '전국', '입내원일수': '96329691', '종별': '1종', '진료건수': '61005932', '진료실인원': '1147555', '진료일수': '478676699', '진료형태': '계', '총진료비(천원)': '5443835740'}, {'기관부담금(천원)': '3031441055', '시도': '전국', '입내원일수': '37763697', '종별': '1종', '진료건수': '2226345', '진료실인원': '365012', '진료일수': '43130721', '진료형태': '입원', '총진료비(천원)': '3031986806'}, {'기관부담금(천원)': '1512928134', '시도': '전국', '입내원일수': '38854295', '종별': '1종', '진료건수': '39067888', '진료실인원': '1101057', '진료일수': '110371962', '진료형태': '외래', '총진료비(천원)': '1558048973'}, {'기관부담금(천원)': '846258300', '시도': '전국', '입내원일수': '19711699', '종별': '1종', '진료건수': '19711699', '진료실인원': '1028970', '진료일수': '325174016', '진료형태': '약국', '총진료비(천원)': '853799960'}, {'기관부담금(천원)': '779748814', '시도': '서울', '입내원일수': '13185805', '종별': '1종', '진료건수': '9514703', '진료실인원': '179395', '진료일수': '76975028', '진료형태': '계', '총진료비(천원)': '788163801'}, {'기관부담금(천원)': '382328645', '시도': '서울', '입내원일수': '3997689', '종별': '1종', '진료건수': '241674', '진료실인원': '47024', '진료일수': '4772046', '진료
# ...

# %%
df = pd.DataFrame(datas)

# %%
# df[df['시도'] == '서울']['총진료비(천원)'].info()
df[df['시도'] == '서울']['총진료비(천원)'].astype(int).sum()
# Out:
# 1576327602

# %%
# 지역별 총진료비 합계를 출력하시오
df['총진료비(천원)'] = df['총진료비(천원)'].astype(float)
df.groupby('시도')['총진료비(천원)'].sum()
# Out:
# 시도
# 부산    9.157824e+08
# 서울    1.576328e+09
# 전국    1.088767e+10
# Name: 총진료비(천원), dtype: float64
