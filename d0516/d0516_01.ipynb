# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows 한글 폰트
matplotlib.rcParams['font.size'] = '10' # font size
matplotlib.rcParams['axes.unicode_minus'] = False # - 기호 깨짐 현상을 해결함
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df.head(3)
# Out:
#        이름   학교  학년    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197  90  85  100  95  85      Python
# 2번    강태원  구로고   3  184  40  35   50  55  25        Java
# 3번    강호림  구로고   2  168  80  75   70  80  75  javascript

# %%
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
plt.bar(df['이름'],df['합계'])
# Out:
# <BarContainer object of 8 artists>

# %%
#산정도 그래프
plt.scatter(df['영어'],df['수학'])
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
plt.scatter(df['영어'],df['수학'])
plt.scatter(df['영어'],df['과학'])

# %%
sizes = np.random.rand(8)

# %%
# 학년별 크기조절 1*500 = 500, 3*500 =1500
sizes = df['학년']*500
plt.scatter(df['영어'],df['수학'],s=sizes,c=df['학년'],cmap='viridis') 
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# 컬럼바 눈금표시 : ticks, 라벨표시 : label, 컬러바크기조절 : shrink, 컬라바위치 하단배치 : orientation='horizontal'
plt.colorbar(ticks=[1,2,3],label = '학년',shrink=0.3,orientation='horizontal')

# %%
# stu_score1 50명만 합계점수 산정도 그래프를 출력하시오
# x 축 이름은 90도로 돌려서 출력하시오
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows 한글 폰트
matplotlib.rcParams['font.size'] = '10' # font size
matplotlib.rcParams['axes.unicode_minus'] = False # - 기호 깨짐 현상을 해결함
df = pd.read_csv('../z20_data/stu_score1.csv')

df.head(50)
plt.scatter(df['id'].head(50),df['total'].head(50))
plt.xticks(rotation=90)
plt.show()
